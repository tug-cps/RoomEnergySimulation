# %%
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Read simulated Data

# %%
data = pd.read_csv(
    './data/output_files_heating_cooling_multiple_parameters__10584_.csv',
    index_col=0,
)

data.index.name = 'Simulation'
data.head()
# Out:
#             Insulation thickness (m)  Window U-value (W/m2K)  \
# Simulation
# 0                              0.001                    1.25
# 1                              0.001                    1.25
# 2                              0.001                    1.25
# 3                              0.001                    1.25
# 4                              0.001                    1.25
#
#             Window SHGC (ratio)  Shading control (W/m2)  \
# Simulation
# 0                           0.2                       0
# 1                           0.2                       0
# 2                           0.2                       0
# 3                           0.2                       0
# 4                           0.2                       0
#
#             Thermostat settings offset (C)  Heating energy (kWh)  \
# Simulation
# 0                                        3                3903.2
# 1                                        2                3643.4
# 2                                        1                3385.4
# 3                                        0                3130.1
# 4                                       -1                2877.4
#
#             Cooling energy (kWh)  Total energy (kWh)
# Simulation
# 0                          379.8              4283.0
# 1                          498.2              4141.6
# 2                          623.3              4008.7
# 3                          752.8              3882.9
# 4                          884.2              3761.6

# %% [markdown]
# # Scatter Matrix

# %%
fig, ax = plt.subplots(figsize=(12, 12), dpi=200)

axes = pd.plotting.scatter_matrix(data, ax=ax, alpha=0.01)

fig.suptitle('Scatter Matrix')

for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')

plt.tight_layout()
# Out:
# /tmp/ipykernel_2209/264925243.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   axes = pd.plotting.scatter_matrix(data, ax=ax, alpha=0.01)

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# # Read simulated Data

# %%
data = pd.read_csv(
    './data/output_files_heating_cooling_multiple_parameters__12348__with wall U-value.csv',
    index_col=0,
)

data.index.name = 'Simulation'
data.head()
# Out:
#             Insulation thickness (m)  Wall U-value (W/m2K)  \
# Simulation
# 0                              0.001                  2.84
# 1                              0.001                  2.84
# 2                              0.001                  2.84
# 3                              0.001                  2.84
# 4                              0.001                  2.84
#
#             Window U-value (W/m2K)  Window SHGC (ratio)  \
# Simulation
# 0                              2.4                  0.2
# 1                              2.4                  0.2
# 2                              2.4                  0.2
# 3                              2.4                  0.2
# 4                              2.4                  0.2
#
#             Shading control (W/m2)  Thermostat settings offset (C)  \
# Simulation
# 0                                0                               3
# 1                                0                               2
# 2                                0                               1
# 3                                0                               0
# 4                                0                              -1
#
#             Heating energy (kWh)  Cooling energy (kWh)  Total energy (kWh)  \
# Simulation
# 0                         5071.7                 340.4              5412.2
# 1                         4756.3                 458.6              5214.9
# 2                         4440.6                 591.6              5032.2
# 3                         4127.0                 728.0              4855.0
# 4                         3816.3                 863.0              4679.4
#
#             Heating energy (kWh/m2)  Cooling energy (kWh/m2)  \
# Simulation
# 0                             219.6                     14.7
# 1                             205.9                     19.9
# 2                             192.2                     25.6
# 3                             178.7                     31.5
# 4                             165.2                     37.4
#
#             Total energy (kWh/m2)
# Simulation
# 0                           234.3
# 1                           225.8
# 2                           217.8
# 3                           210.2
# 4                           202.6

# %% [markdown]
# # Scatter Matrix

# %%
fig, ax = plt.subplots(figsize=(12, 12), dpi=200)

axes = pd.plotting.scatter_matrix(data.iloc[:, :-3], ax=ax, alpha=0.01)

fig.suptitle('Scatter Matrix')

for ax in axes.flatten():
    ax.xaxis.label.set_rotation(90)
    ax.yaxis.label.set_rotation(0)
    ax.yaxis.label.set_ha('right')

plt.tight_layout()
# Out:
# /tmp/ipykernel_862/630546848.py:3: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   axes = pd.plotting.scatter_matrix(data.iloc[:, :-3], ax=ax, alpha=0.01)
